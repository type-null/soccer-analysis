# %% [markdown]
# Relationship between AGE and [G+/xG](https://app.americansocceranalysis.com/#!/mls/xgoals/players)?
#
# NYC FC sky blue:
# - Hex triplet: #87CEEB
# - SRGBB (r, g, b): (135, 206, 235)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# skip first NAN column
xg_df = pd.read_csv('ASA/xgoals_players_2021-03-03.csv').iloc[:, 1:]
gp_df = pd.read_csv('ASA/goals-added_players_2021-03-03.csv').iloc[:, 1:]

# %%
xg_df
# Out:
#                 Player  Team  Season Position  Minutes  Shots  SoT   G     xG  \
# 0    Alejandro Pozuelo   TOR    2020       ST     2162     52   25   9   8.45
# 1          Diego Rossi  LAFC    2020        W     1851     71   34  14  10.94
# 2      Darwin Quintero   HOU    2020        W     1822     59   24   7   6.43
# 3         Robert Beric   CHI    2020       ST     2101     62   29  12  11.25
# 4     Kacper Przybylko   PHI    2020       ST     2160     54   25   8   9.24
# ..                 ...   ...     ...      ...      ...    ...  ...  ..    ...
# 663      Pedro Gallese   ORL    2020       GK     1904      0    0   0   0.00
# 664      Vito Wormgoor   CLB    2020       CB      117      0    0   0   0.00
# 665    Nicolás Acevedo   NYC    2020       DM      189      0    0   0   0.00
# 666          Evan Bush   VAN    2020       GK      793      0    0   0   0.00
# 667        Clint Irwin   COL    2020       GK      392      0    0   0   0.00
#
# ...

# %%
gp_df
# Out:
#                Player  Team  Season Position  Minutes  Dribbling  Fouling  \
# 0      Cristian Pavón   LAG    2020        W     2048       3.34     0.10
# 1       Jordan Morris   SEA    2020        W     1766       1.13    -0.19
# 2         Diego Rossi  LAFC    2020        W     1851      -0.52     0.03
# 3    Anton Tinnerholm   NYC    2020       FB     2210       0.46     0.15
# 4     Darwin Quintero   HOU    2020        W     1822       0.27    -0.20
# ..                ...   ...     ...      ...      ...        ...      ...
# 604     Mauro Manotas   HOU    2020       ST     1454      -0.58    -0.12
# 605      Aljaz Struna   HOU    2020       CB     1575       0.17    -0.47
# 606          Joe Gyau   CIN    2020        W     1961       0.10     0.08
# 607         Yuya Kubo   CIN    2020        W     1412      -0.53    -0.07
# 608       Andrés Ríos   SJE    2020       ST     1845      -1.38    -0.33
#
#      Interrupting  Passing  Receiving  Shooting  Goals Added
# ...

# %%
sorted(xg_df['Position'].unique())
# Out:
# ['AM', 'CB', 'CM', 'DM', 'FB', 'GK', 'ST', 'W']

# %%
sorted(gp_df['Position'].unique())
# Out:
# ['AM', 'CB', 'CM', 'DM', 'FB', 'ST', 'W']
