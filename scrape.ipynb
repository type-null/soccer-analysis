# %% [markdown]
# # Scrape from [transfermarkt](https://www.transfermarkt.com/major-league-soccer/startseite/wettbewerb/MLS1)

# %%
import bs4
import sys
import requests
import re
import pandas as pd
import numpy as np

# %%
def get_team_links(season):
    # season = 2020
    df = pd.DataFrame(columns=['team_name', 'club', 'team_num', 'link', 'season'])
    user_agent = "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:68.0) Gecko/20100101 Firefox/68.0"
    url = f'https://www.transfermarkt.com/major-league-soccer/startseite/wettbewerb/MLS1/plus/?saison_id={season}'
    response = requests.get(url, headers={'User-Agent': user_agent})
    content = response.content.decode('utf-8')
    soup = bs4.BeautifulSoup(content, 'html.parser')
    table = soup.find('table', attrs={'class':'items'}).find('tbody')
    rows = table.find_all('tr')
    for row in rows:
        club = row.find('a').find('img')['alt']
        info = row.find('a')['href'].split('/')
        team_name = info[1]
        team_num = info[4]
        team_link = f"https://www.transfermarkt.com/{team_name}/kader/verein/{team_num}/saison_id/{season}/plus/1"
        df.loc[len(df.index)] = [team_name, club, team_num, team_link, season]
    return df

# %%
team_links = get_team_links(2020)

# %%
def get_player_bio(team_links_row):
    err = []
    df = pd.DataFrame(columns=['first_name', 'last_name', 'player', 'club', 'bday', 'join', 'value', 'season'])
    url = team_links_row['link']
    season = team_links_row['season']
    club = team_links_row['club']
    user_agent = "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:68.0) Gecko/20100101 Firefox/68.0"
    response = requests.get(url, headers={'User-Agent': user_agent})
    content = response.content.decode('utf-8')
    soup = bs4.BeautifulSoup(content, 'html.parser')
    table = soup.find('table', attrs={'class':'items'}).find('tbody')
    rows = table.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        info = [ele.text.strip() for ele in cols]
        if len(info) > 3:
            s = [idx for idx in range(len(info[3])) if info[3][idx].isupper()][-2]
            name = info[3][:s]
            try:
                first, *last_temp = name.split()
                last = " ".join(last_temp).strip('.').strip()
            except:
                err.append([club, name])
                continue
            title = info[4]
            bday = info[5].split('(')[0].strip()
            if len(bday) < 8:
                bday = None
            height = info[7]
            foot = info[8]
            join = info[9]
            value = info[12]
            ddf = {
                'first_name': first,
                'last_name': last,
                'player': ". ".join([first[0].upper(), last]),
                'club': club,
                'bday': bday,
                'join': join,
                'value': value,
                'season': season
            }
            df = df.append(ddf, ignore_index=True)
            
    df['bday'] = pd.to_datetime(df['bday'])
    df['join'] = pd.to_datetime(df['join'])
    now = pd.Timestamp('now')
    df['age'] = (now - df['bday']).astype('<m8[Y]')
    df['join_age'] = (df['join'] - df['bday']).astype('<m8[Y]')
    
    df = df.drop(columns=['bday', 'join'])
        
    return df

# %%
dfs = []
for i in range(len(team_links)):
    dfs.append(get_player_bio(team_links.loc[i]))

player_df = pd.concat(dfs, ignore_index=True)
# Out:
#       first_name last_name       player                 club    value season  \
# 0        Kenneth   Vermeer   K. Vermeer       Los Angeles FC  €800Th.   2020
# 1          Pablo  Sisniega  P. Sisniega       Los Angeles FC  €500Th.   2020
# 2          Tomás    Romero    T. Romero       Los Angeles FC  €100Th.   2020
# 3          Eddie    Segura    E. Segura       Los Angeles FC   €2.50m   2020
# 4          Jesús   Murillo   J. Murillo       Los Angeles FC   €1.20m   2020
# ..           ...       ...          ...                  ...      ...    ...
# 723         Tate   Schmitt   T. Schmitt  Real Salt Lake City  €200Th.   2020
# 724  Christopher    Garcia    C. Garcia  Real Salt Lake City  €100Th.   2020
# 725      Douglas  Martínez  D. Martínez  Real Salt Lake City  €600Th.   2020
# 726        Rubio     Rubin     R. Rubin  Real Salt Lake City  €400Th.   2020
# 727        Milan    Iloski    M. Iloski  Real Salt Lake City  €100Th.   2020
#
#       age  join_age
# 0    35.0      34.0
# 1    25.0      23.0
# 2    20.0      20.0
# 3    24.0      22.0
# 4    27.0      26.0
# ..    ...       ...
# 723  23.0      21.0
# 724  18.0      17.0
# 725  23.0      22.0
# 726  25.0      24.0
# 727  21.0      20.0
#
# [728 rows x 8 columns]

# %%
player_df = pd.concat(dfs, ignore_index=True)

# %%
player_df.to_csv('data/player_bio.csv')

# %%
def get_one_page(season, page=None):
    user_agent = "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:68.0) Gecko/20100101 Firefox/68.0"
    url = f'https://www.mlssoccer.com/stats/season?page={page}&franchise=select&year={season}'
    response = requests.get(url, headers={'User-Agent': user_agent})
    content = response.content.decode('utf-8')
    soup = bs4.BeautifulSoup(content, 'html.parser')
    table = soup.find('tbody')
    rows = table.find_all('tr')
    cols = rows[0].find_all('td')
    df = pd.DataFrame(columns=[ele['data-title'] for ele in cols])
    for row in rows:
        cols = row.find_all('td')
        df.loc[len(df.index)] = [ele.text.strip() for ele in cols]
    return df

def get_player_stats(season):
    last = 27 # last page number, manually input here
    dfs = [get_one_page(season, page=p) for p in range(last)]
    return pd.concat(dfs, ignore_index=True)

# %%
stat_df = get_player_stats(2020)

# %%
stat_df.to_csv("data/play_time.csv")

# %%
sorted(player_df['club'].unique())
# Out:
# ['Atlanta United FC',
#  'Austin FC',
#  'Chicago Fire FC',
#  'Club de Foot Montréal',
#  'Colorado Rapids',
#  'Columbus Crew SC',
#  'D.C. United',
#  'FC Cincinnati',
#  'FC Dallas',
#  'Houston Dynamo FC',
#  'Inter Miami CF',
#  'Los Angeles FC',
#  'Los Angeles Galaxy',
#  'Minnesota United FC',
#  'Nashville SC',
#  'New England Revolution',
#  'New York City FC',
#  'New York Red Bulls',
#  'Orlando City SC',
#  'Philadelphia Union',
#  'Portland Timbers',
#  'Real Salt Lake City',
#  'San Jose Earthquakes',
#  'Seattle Sounders FC',
#  'Sporting Kansas City',
#  'Toronto FC',
#  'Vancouver Whitecaps FC']

# %%
sorted(stat_df['Club'].unique())
# Out:
# ['ATL',
#  'ATX',
#  'CHI',
#  'CIN',
#  'CLB',
#  'CLT',
#  'COL',
#  'DAL',
#  'DC',
#  'HOU',
#  'LA',
#  'LAFC',
#  'LFC',
#  'MCF',
#  'MIA',
#  'MIN',
#  'MTL',
#  'NE',
#  'NSH',
#  'NY',
#  'NYC',
#  'ORL',
#  'PHI',
#  'POR',
#  'RBNY',
#  'RSL',
#  'SEA',
#  'SJ',
#  'SKC',
#  'TOR',
#  'VAN']

# %% [markdown]
# GP: Games Played, GS: Games Started, G: Goals, MIN: Minutes Played, A: Assists, SHT: Shots, SOG: Shots on Goal, GWG: Game Winning Goal, FC: Fouls Committed, FS: Fouls Suffered, Y: Yellow Cards, R: Red Cards, GF: Goals For, GA: Goals Against, SO: Shutouts, SV: Saves, CK: Corner Kicks, PKA: Penalty Kick Attempts, PKG: Penalty Kick Goals, PKS: Penalty Kick Saves, OFF: Offsides, SC%: G/SHTS

# %%
14/0.74
# Out:
# 18.91891891891892

# %%
stat_df['name'] = stat_df['Player']
stat_df
# Out:
#                Player  Club POS  GP  GS  MINS   G  A SHTS SOG GWG PKG/A HmG  \
# 0         Diego Rossi  LAFC   F  19  19  1698  14  4   71  34   1   1/1  11
# 1        Gyasi Zardes   CLB   F  21  20  1717  12  4   41  19   2   0/2   8
# 2        Raul Ruidiaz   SEA   F  17  17  1427  12  4   55  23   4   1/1   8
# 3        Robert Beric   CHI   F  23  22  1931  12  1   62  29   1   1/2   7
# 4       Jordan Morris   SEA   F  22  18  1724  10  8   39  18   3   0/0   8
# ..                ...   ...  ..  ..  ..   ...  .. ..  ...  ..  ..   ...  ..
# 668  Sebastian Mendez   ORL   M  19  11  1087   0  0   17   3   0   0/0   0
# 669        Kelyn Rowe   SEA   M  16  10   896   0  0   17   4   0   0/0   0
# 670      Siem de Jong   CIN   M  15   8   793   0  0   18   5   0   0/1   0
# 671     Maxime Chanot   NYC   D  20  20  1712   0  0   19   4   0   0/0   0
# 672     Nicolas Figal   MIA   D  21  21  1746   0  0   22   9   0   0/0   0
#
#     RdG G/90min   SC%              name
# 0     3    0.74  19.7       Diego Rossi
# 1     4    0.63  29.3      Gyasi Zardes
# 2     4    0.76  21.8      Raul Ruidiaz
# 3     5    0.56  19.4      Robert Beric
# 4     2    0.52  25.6     Jordan Morris
# ..   ..     ...   ...               ...
# 668   0    0.00   0.0  Sebastian Mendez
# 669   0    0.00   0.0        Kelyn Rowe
# 670   0    0.00   0.0      Siem de Jong
# 671   0    0.00   0.0     Maxime Chanot
# 672   0    0.00   0.0     Nicolas Figal
#
# [673 rows x 17 columns]

# %%
player_df = pd.read_csv("data/player_bio.csv")
stat_df = pd.read_csv("data/play_time.csv")

# %%
from unidecode import unidecode

player_df['first_name'] = player_df['first_name'].apply(unidecode)
player_df['last_name'] = player_df['last_name'].apply(unidecode)

player_df['Player'] = player_df['first_name'] +" "+ player_df['last_name']
player_df = player_df[['player', 'club', 'value', 'age','join_age','Player']]
player_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ad7468f432e3> in <module>
#       1 from unidecode import unidecode
#       2
# ----> 3 player_df['first_name'] = player_df['first_name'].apply(unidecode)
#       4 player_df['last_name'] = player_df['last_name'].apply(unidecode)
#       5
#
# NameError: name 'player_df' is not defined

# %%
player_df['Player'][264] = 'Ismael Tajouri-Shradi'
player_df['Player'][257] = 'Juan Pablo Torres'
player_df['Player'][261] = 'Maximiliano Moralez'
# Out:
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
stat_df = stat_df[['Player', 'Club', 'MINS', 'POS']]
stat_df['Player'] = stat_df['Player'].apply(unidecode)
stat_df
# Out:
#                Player  Club  MINS POS
# 0         Diego Rossi  LAFC  1698   F
# 1        Gyasi Zardes   CLB  1717   F
# 2        Raul Ruidiaz   SEA  1427   F
# 3        Robert Beric   CHI  1931   F
# 4       Jordan Morris   SEA  1724   F
# ..                ...   ...   ...  ..
# 668  Sebastian Mendez   ORL  1087   M
# 669        Kelyn Rowe   SEA   896   M
# 670      Siem de Jong   CIN   793   M
# 671     Maxime Chanot   NYC  1712   D
# 672     Nicolas Figal   MIA  1746   D
#
# [673 rows x 4 columns]

# %%
df_raw = pd.merge(stat_df, player_df, on='Player', how='left')

# %%
df = df_raw.dropna(subset=['club'])

# %%
df.reset_index(drop=True)
# Out:
#              Player  Club  MINS POS       player                 club  \
# 0       Diego Rossi  LAFC  1698   F     D. Rossi       Los Angeles FC
# 1      Gyasi Zardes   CLB  1717   F    G. Zardes     Columbus Crew SC
# 2      Raul Ruidiaz   SEA  1427   F   R. Ruidíaz  Seattle Sounders FC
# 3      Robert Beric   CHI  1931   F     R. Beric      Chicago Fire FC
# 4     Chris Mueller   ORL  1477   F   C. Mueller      Orlando City SC
# ..              ...   ...   ...  ..          ...                  ...
# 470   Marcelo Silva   RSL  1309   D     M. Silva  Real Salt Lake City
# 471   Boniek Garcia   HOU   819   M    B. García    Houston Dynamo FC
# 472  Sacha Kljestan    LA   769   M  S. Kljestan   Los Angeles Galaxy
# 473      Kelyn Rowe   SEA   896   M      K. Rowe  Seattle Sounders FC
# 474   Maxime Chanot   NYC  1712   D    M. Chanot     New York City FC
#
#        value   age  join_age
# 0    €20.00m  23.0      19.0
# 1     €3.50m  29.0      26.0
# 2     €7.00m  30.0      27.0
# 3     €3.00m  29.0      28.0
# 4     €3.00m  24.0      21.0
# ..       ...   ...       ...
# 470  €400Th.  31.0      28.0
# 471  €200Th.  36.0      27.0
# 472  €350Th.  35.0      34.0
# 473  €600Th.  29.0      29.0
# 474   €1.00m  31.0      26.0
#
# [475 rows x 9 columns]

# %%
nyc_df = df[df['Club']=='NYC'].reset_index(drop=True)
nyc_df
# Out:
#                     Player Club  MINS POS              player  \
# 0     Valentin Castellanos  NYC  1341   F      V. Castellanos
# 1             Jesus Medina  NYC  1495   M           J. Medina
# 2         Anton Tinnerholm  NYC  2001   D       A. Tinnerholm
# 3    Ismael Tajouri-Shradi  NYC   670   F  I. Tajouri-ShradiI
# 4             Keaton Parks  NYC  1733   M            K. Parks
# 5        Alexander Callens  NYC  1934   D          A. Callens
# 6      Maximiliano Moralez  NYC   875   M          M. Moralez
# 7               Tony Rocha  NYC    51   M            T. Rocha
# 8   Gudmundur Thorarinsson  NYC   683   D     G. Thórarinsson
# 9              James Sands  NYC  1409   M            J. Sands
# 10       Juan Pablo Torres  NYC     2   M           J. Torres
# 11       Sebastien Ibeagha  NYC   282   D          S. Ibeagha
# 12             Tayvon Gray  NYC     0   D             T. Gray
# 13             Justin Haak  NYC     0   M             J. Haak
# 14         Nicolas Acevedo  NYC   128   M          N. Acevedo
# 15           Maxime Chanot  NYC  1712   D           M. Chanot
#
#                 club    value   age  join_age
# 0   New York City FC   €4.00m  22.0      20.0
# 1   New York City FC   €3.00m  23.0      20.0
# 2   New York City FC   €2.50m  30.0      26.0
# 3   New York City FC   €1.00m  26.0      23.0
# 4   New York City FC   €3.00m  23.0      22.0
# 5   New York City FC   €1.80m  28.0      24.0
# 6   New York City FC   €1.50m  34.0      29.0
# 7   New York City FC  €450Th.  27.0      25.0
# 8   New York City FC  €800Th.  28.0      27.0
# 9   New York City FC   €2.50m  20.0      16.0
# 10  New York City FC  €150Th.  21.0      19.0
# 11  New York City FC  €500Th.  29.0      26.0
# 12  New York City FC   €50Th.  18.0      17.0
# 13  New York City FC  €200Th.  19.0      17.0
# 14  New York City FC   €2.00m  21.0      20.0
# 15  New York City FC   €1.00m  31.0      26.0

# %%
df.to_csv('data/combine.csv')

# %%
import re

def convert_currency(s):
    a = re.findall(r'[A-Za-z]+.?', s)
    if a:
        if re.findall(r'[A-Za-z]+.?', s)[0] == 'm':
            return float(re.findall(r'\d+', s)[0])*1000000*1.18
        elif re.findall(r'[A-Za-z]+.?', s)[0] == 'Th.':
            return float(re.findall(r'\d+', t)[0])*1000*1.18
    return None

# %%
df['usd'] = df['value'].apply(convert_currency)
# Out:
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#              Player  Club  MINS POS       player                 club  \
# 0       Diego Rossi  LAFC  1698   F     D. Rossi       Los Angeles FC
# 1      Gyasi Zardes   CLB  1717   F    G. Zardes     Columbus Crew SC
# 2      Raul Ruidiaz   SEA  1427   F   R. Ruidíaz  Seattle Sounders FC
# 3      Robert Beric   CHI  1931   F     R. Beric      Chicago Fire FC
# 5     Chris Mueller   ORL  1477   F   C. Mueller      Orlando City SC
# ..              ...   ...   ...  ..          ...                  ...
# 664   Marcelo Silva   RSL  1309   D     M. Silva  Real Salt Lake City
# 665   Boniek Garcia   HOU   819   M    B. García    Houston Dynamo FC
# 667  Sacha Kljestan    LA   769   M  S. Kljestan   Los Angeles Galaxy
# 670      Kelyn Rowe   SEA   896   M      K. Rowe  Seattle Sounders FC
# 672   Maxime Chanot   NYC  1712   D    M. Chanot     New York City FC
#
#        value   age  join_age         usd
# 0    €20.00m  23.0      19.0  23600000.0
# 1     €3.50m  29.0      26.0   3540000.0
# 2     €7.00m  30.0      27.0   8260000.0
# 3     €3.00m  29.0      28.0   3540000.0
# 5     €3.00m  24.0      21.0   3540000.0
# ..       ...   ...       ...         ...
# 664  €400Th.  31.0      28.0    472000.0
# 665  €200Th.  36.0      27.0    472000.0
# 667  €350Th.  35.0      34.0    472000.0
# 670  €600Th.  29.0      29.0    472000.0
# 672   €1.00m  31.0      26.0   1180000.0
#
# [475 rows x 10 columns]

# %%
float(re.findall(r'\d+', t)[0])*1000*1.18
# Out:
# 472000.0

# %%
df.to_csv("data/usd.csv")

# %%
age_df = pd.read_csv("data/player_bio.csv", usecols=range(1,9))
stat_df = pd.read_csv("data/play_time.csv", usecols=range(1,17))
g_df = pd.read_csv("ASA/goals-added_players_2021-03-03.csv", usecols=range(1,13))

# %%
age_df
# Out:
#       first_name last_name       player                 club    value  season  \
# 0        Kenneth   Vermeer   K. Vermeer       Los Angeles FC  €800Th.    2020
# 1          Pablo  Sisniega  P. Sisniega       Los Angeles FC  €500Th.    2020
# 2          Tomás    Romero    T. Romero       Los Angeles FC  €100Th.    2020
# 3          Eddie    Segura    E. Segura       Los Angeles FC   €2.50m    2020
# 4          Jesús   Murillo   J. Murillo       Los Angeles FC   €1.20m    2020
# ..           ...       ...          ...                  ...      ...     ...
# 723         Tate   Schmitt   T. Schmitt  Real Salt Lake City  €200Th.    2020
# 724  Christopher    Garcia    C. Garcia  Real Salt Lake City  €100Th.    2020
# 725      Douglas  Martínez  D. Martínez  Real Salt Lake City  €600Th.    2020
# 726        Rubio     Rubin     R. Rubin  Real Salt Lake City  €400Th.    2020
# 727        Milan    Iloski    M. Iloski  Real Salt Lake City  €100Th.    2020
#
#       age  join_age
# 0    35.0      34.0
# 1    25.0      23.0
# 2    20.0      20.0
# 3    24.0      22.0
# 4    27.0      26.0
# ..    ...       ...
# 723  23.0      21.0
# 724  18.0      17.0
# 725  23.0      22.0
# 726  25.0      24.0
# 727  21.0      20.0
#
# [728 rows x 8 columns]

# %%
from unidecode import unidecode

g_df['name'] = g_df['Player'].apply(unidecode)
g_df
# Out:
#                Player  Team  Season Position  Minutes  Dribbling  Fouling  \
# 0      Cristian Pavón   LAG    2020        W     2048       3.34     0.10
# 1       Jordan Morris   SEA    2020        W     1766       1.13    -0.19
# 2         Diego Rossi  LAFC    2020        W     1851      -0.52     0.03
# 3    Anton Tinnerholm   NYC    2020       FB     2210       0.46     0.15
# 4     Darwin Quintero   HOU    2020        W     1822       0.27    -0.20
# ..                ...   ...     ...      ...      ...        ...      ...
# 604     Mauro Manotas   HOU    2020       ST     1454      -0.58    -0.12
# 605      Aljaz Struna   HOU    2020       CB     1575       0.17    -0.47
# 606          Joe Gyau   CIN    2020        W     1961       0.10     0.08
# 607         Yuya Kubo   CIN    2020        W     1412      -0.53    -0.07
# 608       Andrés Ríos   SJE    2020       ST     1845      -1.38    -0.33
#
#      Interrupting  Passing  Receiving  Shooting  Goals Added              name
# 0           -0.10    -0.02      -0.14      0.34         3.52    Cristian Pavon
# 1           -0.21     0.11       2.18      0.15         3.16     Jordan Morris
# 2            0.17     0.15       2.01      1.12         2.95       Diego Rossi
# 3            0.64     1.15       0.20      0.25         2.85  Anton Tinnerholm
# 4           -0.21     2.15      -0.23      0.67         2.44   Darwin Quintero
# ..            ...      ...        ...       ...          ...               ...
# 604         -0.14    -0.88      -0.23     -0.06        -2.01     Mauro Manotas
# 605         -1.69    -0.04      -0.26      0.01        -2.28      Aljaz Struna
# 606         -0.21    -1.49      -0.53     -0.30        -2.35          Joe Gyau
# 607         -0.14    -0.71      -0.73     -0.20        -2.38         Yuya Kubo
# 608         -0.23    -0.40       0.15     -0.21        -2.40       Andres Rios
#
# [609 rows x 13 columns]

# %%
age_df['first_name'] = age_df['first_name'].apply(unidecode)
age_df['last_name'] = age_df['last_name'].apply(unidecode)

age_df['name'] = age_df['first_name'] +" "+ age_df['last_name']
age_df = age_df[['player', 'club', 'value', 'age','join_age','name']]

age_df['name'][264] = 'Ismael Tajouri-Shradi'
age_df['name'][257] = 'Juan Pablo Torres'
age_df['name'][261] = 'Maximiliano Moralez'
age_df
# Out:
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/solgaleo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#           player                 club    value   age  join_age  \
# 0     K. Vermeer       Los Angeles FC  €800Th.  35.0      34.0
# 1    P. Sisniega       Los Angeles FC  €500Th.  25.0      23.0
# 2      T. Romero       Los Angeles FC  €100Th.  20.0      20.0
# 3      E. Segura       Los Angeles FC   €2.50m  24.0      22.0
# 4     J. Murillo       Los Angeles FC   €1.20m  27.0      26.0
# ..           ...                  ...      ...   ...       ...
# 723   T. Schmitt  Real Salt Lake City  €200Th.  23.0      21.0
# 724    C. Garcia  Real Salt Lake City  €100Th.  18.0      17.0
# 725  D. Martínez  Real Salt Lake City  €600Th.  23.0      22.0
# 726     R. Rubin  Real Salt Lake City  €400Th.  25.0      24.0
# 727    M. Iloski  Real Salt Lake City  €100Th.  21.0      20.0
#
#                    name
# 0       Kenneth Vermeer
# 1        Pablo Sisniega
# 2          Tomas Romero
# 3          Eddie Segura
# 4         Jesus Murillo
# ..                  ...
# 723        Tate Schmitt
# 724  Christopher Garcia
# 725    Douglas Martinez
# 726         Rubio Rubin
# 727        Milan Iloski
#
# [728 rows x 6 columns]

# %%
df_raw = pd.merge(age_df, g_df, on='name', how='left')
df = df_raw.dropna(subset=['Fouling'])
df = df.reset_index(drop=True)

# %%
df.to_csv("data/age_g+.csv")
